# %% [markdown]
# # Introduction to the exercise
# In this exercise you will implement and apply PCA to a database consisting of face shapes. The exercise lays the foundations for assignment 2.
#
# <article class="message">
#     <div class="message-body">
#         <strong>List of individual tasks</strong>
#         <ul style="list-style: none;">
#             <li>
#             <a href="#eval">Task 1: Reflection on reconstruction</a>
#             </li>
#             <li>
#             <a href="#implementation">Task 2: Dimensionality reduction and reconstruct…</a>
#             </li>
#             <li>
#             <a href="#eval2">Task 3: Evaluating reconstruction error</a>
#             </li>
#         </ul>
#     </div>
# </article>
#
# <article class="message is-danger">
#   <div class="message-header">Important</div>
#   <div class="message-body">
#
#   This exercise and the in-class exercise are very similar, but use different datasets. In this exercise you should use your implementation from the in-class exercise, but we advise that you actually go through the steps again to understand the algorithm and not only the results.
#
#
#   </div>
# </article>
# ## Data
# The dataset used for the assigment consists of 120 landmarks (2D points) of faces (data space). A face consists of 73 (x,y)-coordinate pairs, i.e. 146 featues in total.
# The following cell imports the necessary libraries, loads the data and uses the function `plot_many_faces`
#  to  visualize 6 faces.

# %%
import matplotlib.pyplot as plt
import numpy as np

from pca_utils import *

path = './db'
shapes, images = face_shape_data(path)
plot_many_faces(shapes[:6])

# %% [markdown]
# ## Implementing PCA
# An application of principal component analysis is about finding a linear projection (transformation)
# that reduces the number of dimensions used to represent the data while
# retaining a certain proportion of the total variation.
# Let $X$ $\in \mathbb{R}^{N \times D}$ be the data matrix, $C$ $\in \mathbb{R}^{D \times D}$ the covariance matrix of $X$, and $V$ $\in \mathbb{R}^{D \times D}$ the matrix of eigenvectors of $C$:
#
# $$
#
# {V} = \begin{bmatrix} | & | & & | \\ {v}_1 & {v}_2 & \cdots & {v}_D  \\ | & | & & | \end{bmatrix}.
#
# $$
# Assume, the eigenvectors ${v}_i$ are sorted according to their eigenvalues $\lambda_i$. The eignevalue of the covariance matrix $\lambda_i$ gives the variance along the eignevector directions. The sum of all eigenvalues $\lambda^{(1)}+\dots+\lambda^{(D)}$ gives the total variance of the data.
# (1) **Proportional variance** is the proportion of the total variance explained by a single component.
#
# $$\frac{\lambda^{(i)}}{\lambda^{(1)} + \dots + \lambda^{(D)}}$$
# (2) **Cumulative variance** is the cumulative proportion of the total variance explained by the first $k$ components.
#
# $$\frac{\lambda^{(1)} + \dots + \lambda^{(k)}}{\lambda^{(1)} + \dots + \lambda^{(D)}}$$
# Define $\Phi_k$, as the $D\times k$ matrix of the first $k$ eigenvectors of $V$:
#
# $$
#
# {\Phi} = \begin{bmatrix} | & | & & | \\ {v}_1 & {v}_2 & \cdots & {v}_k \\ | & | & & | \end{bmatrix}.
#
# $$
# The column vectors of ${\Phi_k}$ constitute the orthonormal basis of the latent space. ${\Phi_k}$ can be used to transform data points between the data space and the latent space. The mapping of a point $x$ from data space to latent space is given by:
#
# $$
# \mathbf{a} = \mathbf{\Phi_k}^\top(\mathbf{x}-\mathbf{\mu}),
# $$
# and back into data space:
#
# $$
# x  = \mathbf{\Phi_k} \mathbf{a} + \mathbf{\mu}
# $$
# If $k = D$ (keeping all dimensions) will result in no data loss because it is a change of basis in the same $D$ dimensions. Retaining  $k<D$  principal components and consequently discarding the remaining  $r = D - k$  components, it is effectively assumed that these $r$ components do not contain significant information, e.g. noise. The percentage of the total variance that is removed is given by:
#
# $$\frac{\lambda^{(D-k)} + \dots + \lambda^{(D)}}{\lambda^{(1)} + \dots + \lambda^{(D)}}$$
# where  $\lambda^{(i)}$  are the eigenvalues sorted in descending order $( \lambda^{(1)} \geq \lambda^{(2)} \geq \dots \geq \lambda^{(D)} )$.
# That is there will be a _reconstruction error_ $\epsilon = x - \tilde{x}$,  by first mapping the data $x$ to latent space by $\mathbf{a} = \mathbf{\Phi_k}^\top(\mathbf{x}-\mathbf{\mu})$ and then  back to data space by $\tilde{x}  = \mathbf{\Phi_k} \mathbf{a} + \mathbf{\mu}$.
# <article class="message task"><a class="anchor" id="eval"></a>
#     <div class="message-header">
#         <span>Task 1: Reflection on reconstruction</span>
#         <span class="has-text-right">
#           <i class="bi bi-lightbulb-fill"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# 1. Why do we get a reconstruction error $\epsilon$?
# 2. What is the expected error $\epsilon$ when $k=D$?
# 3. (Optional) Show 2 mathematically.
# 4. How does the expected error change when we decrease $k$?
#
#
#
# </div></article>

# %%
'''
1. Why do we get a reconstruction error ε?
Due to removing r many dimension from the dimensions (D) we get a reconstruction error ε.
So when re-projecting the data back to the original dimensions, we get this reconstruction error ε since we have lost r (r = D - k) dimensions of information.
Though it is important to note that ε is not equal to r.
r specifies the omitted dimensions, while ε specifies the error in the reconstruction of the original data.

2. What is the expected error ε when k = D?
The expected error ε when k = D is 0.
This is due to all the dimensions being used and thus all of the data being captured.add()

3. (Optional) Show 2 mathematically.
2 = 2 (done)

4. How does the expected error change when we decrease k?
It will in general increase the error ε as we loose more and more dimensions which increase r.
'''

# %% [markdown]
# The next task is about implementing PCA and transforming data between data space and latent space.
# <article class="message task"><a class="anchor" id="implementation"></a>
#     <div class="message-header">
#         <span>Task 2: Dimensionality reduction and reconstruction</span>
#         <span class="has-text-right">
#           <i class="bi bi-code"></i><i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# 1. **Complete PCA:** Following the comments in the function template, complete the `get_principle_components`
#  function below to calculate and return all principle components of the dataset. **Make sure to center the samples (subtract the mean before calculating the covariance matrix)**.
#
# 2. **Calculate variance:** Complete the `variance_proportion_plot`
#  function according to the comments in the function template to calculate the _proportional_ and _cumulative_ variance. The function already includes code to plot both on a single graph. Once the function is complete, generate the plot to display the _proportional_ and _cumulative_ variances.
#
# 3. Complete the `transform_to_latent_space`
#  function that transforms the data from the data space to latent space
# ( [Equation 1](#eq:trans) )
#
#
#
# $$
#  \mathbf{a} = \mathbf{\Phi}^\top(\mathbf{x}-\mathbf{\mu})
# $$
# 4. Complete the `transform_from_latent_space`
#  function that transforms the data from the  latent space to the data space
# ( [Equation 2](#eq:inv) ).
#
#
# $$
#  \mathbf{x} = \mathbf{\Phi} \mathbf{a} + \mathbf{\mu}
# $$
# <article class="message is-warning">
#   <div class="message-header">Tip</div>
#   <div class="message-body">
#
#   Some of the later tasks will be easier if you return all 146 principle components. You can then create another function for extracting $k$ components to generate $\Phi_k$.
#
#
#   </div>
# </article>
#
#
# </div></article>

# %%
## 1

def get_principle_components(X):
    """Calculates principle components for X.

    Args:
        X: The dataset. An NxD array were N are the number of samples and D are
        the number of features.

    Returns:
        Tuple (components, eigenvalues, mu) where components is a DxD matrix of
        principle components, eigenvalues is a D-element vector of
        corresponding eigenvalues, and mu is a D-element array containing the mean
        vector.
    """
    mu = np.mean(X, axis=0) # find the mean of the data
    X_centered = X - mu # center the data
    cm = np.cov(X_centered, rowvar=False) # calculate the covariance matrix
    e_val, e_vec = np.linalg.eigh(cm) # calculate the eigenvalues and eigenvectors
    
    # reverse the eigenvalues and eigenvectors
    e_val = e_val[::-1]
    e_vec = e_vec[:, ::-1]

    return e_vec, e_val, mu

    
## 2 

def variance_proportion_plot(pc_values, max=1):
    """
    Plots the cumulative and individual variance proportions for principal components.

    Args:
        pc_values: 1D array of eigenvalues representing the variance explained by each principal component.
        max: Maximum cumulative variance proportion to display (between 0 and 1).

    Returns:
        None. Displays a plot of cumulative and individual variance proportions.
    """
    # Calculate total variance, cumulative variance, and individual variance proportions
    total = np.sum(pc_values)
    cumulative = np.cumsum(pc_values)
    proportion = cumulative / total
    # Individual variance proportion for each component
    each = pc_values / total
    

    # Find the minimum number of components required to reach the desired cumulative variance
    max_idx = np.argwhere(proportion >= max - 1e-7)[0, 0]
    
    # Set the x-axis values (number of components) up to the determined threshold
    x = np.arange(1, max_idx + 1, 1)

    # Create the plot
    plt.figure()
    plt.xlabel('Number of components')
    plt.ylabel('Variance (fraction of total)')
    
    # Plot cumulative variance proportion and individual variance proportion
    plt.plot(x, proportion[:max_idx], 'r-+', label='Cumulative variance')
    plt.plot(x, each[:max_idx], 'b-+', label='Variance proportion')

    # Set the y-axis limit and add a legend
    plt.ylim(0, 1)
    plt.legend(['Cumulative variance', 'Variance proportion'])
    
    # Display the plot
    plt.show()


comp, val, mu = get_principle_components(shapes)
variance_proportion_plot(val)


## 3

def transform_to_latent_space(X, principle_components, mu):
    """Transforms X to an k-dimensional space where k is the number of
    principle_components.

    Args:
        X: The dataset. An NxD array were N are the number of samples and M are
        the number of features.
        principle_components: An Dxk matrix containing the principle
        components.
        mu: A D-element array containing the mean vector.

    Returns:
        A Nxk array describing the transformed data.
    """
    return (X - mu) @ principle_components


## 4

def transform_from_latent_space(v, principle_components, mu):
    """Reverses the dimensionality reduction of v, a Nxk matrix where
    k is the number of principle components. The result is a NxD matrix.

    Args:
        v: The transformed (latent space) dataset with size Nxk.
        principle_components: An Dxk matrix containing the principle
        components.
        mu: A D-element array containing the mean vector.

    Returns:
        An NxD array reconstruction of the original feature vectors X.
    """
    return v @ principle_components.T + mu

# %% [markdown]
# ## Reconstruction error
# This task involves implementing a method to calculate the reconstruction error and using it to examine the impact of varying the number of principal components. The root mean square error (RMSE) is used for calculating the reconstruction error:
#
# $$RMSE(x, \widetilde{x}) = \sqrt{\frac{1}{N}\sum_i (x_i-\widetilde{x}_i)^2},$$
# where $x$, $\widetilde{x}$ are the original and transformed samples
# respectively and $N$ is the total number of samples $x_i$.
# <article class="message task"><a class="anchor" id="eval2"></a>
#     <div class="message-header">
#         <span>Task 3: Evaluating reconstruction error</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# 1. **Calculate reconstruction error:** Complete the `reconstruction_error`
#  function according to the comments in the function template to calculate the reconstruction error.
#
# 2. **Plot reconstruction error:** Use the  `reconstruction_error_plot`
#  function to plot the reconstruction error for $k=1 .... D$.
#
#
#
#
# </div></article>

# %%
def reconstruction_error(X, principal_components, mu):
    """
    Calculates the reconstruction error after projecting data into a lower-dimensional space
    and then reconstructing it back to the original space. 

    Args:
        X: Original data matrix with shape NxD, where N is the number of samples and D is
           the number of original features.
        principal_components: A Dxk matrix containing the principal components used for 
           dimensionality reduction, where k is the number of components.
        mu: A D-element array representing the mean vector of the original data.

    Returns:
        The reconstruction error as a single float, representing the root mean squared
        error between the original and reconstructed data.
    """
    latent_space = transform_to_latent_space(X, principal_components, mu)

    reconstructed_X = transform_from_latent_space(latent_space, principal_components, mu)

    print("Original X shape:", X.shape)
    print("Principal components shape:", principal_components.shape)
    print("Latent space shape:", latent_space.shape)
    print("Reconstructed X shape:", reconstructed_X.shape)

    return np.sqrt(np.mean((X - reconstructed_X) ** 2))

def reconstruction_error_plot(X, principal_components, mu):
    errs = []
    for i in range(len(principal_components)):
        errs.append(reconstruction_error(X, principal_components[:, :i], mu))

    x = np.arange(1, len(principal_components) + 1, 1)

    plt.figure()
    plt.xlabel('Number of components')
    plt.ylabel('RMSE')
    plt.plot(x, errs, 'r-+')
    plt.legend(['Reconstruction error (RMSE)'])
    plt.show()


reconstruction_error_plot(shapes, comp, mu)
# Out:
# Original X shape: (120, 146)
# Principal components shape: (146, 0)
# Latent space shape: (120, 0)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 1)
# Latent space shape: (120, 1)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 2)
# Latent space shape: (120, 2)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 3)
# Latent space shape: (120, 3)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 4)
# Latent space shape: (120, 4)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 5)
# Latent space shape: (120, 5)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 6)
# Latent space shape: (120, 6)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 7)
# Latent space shape: (120, 7)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 8)
# Latent space shape: (120, 8)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 9)
# Latent space shape: (120, 9)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 10)
# Latent space shape: (120, 10)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 11)
# Latent space shape: (120, 11)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 12)
# Latent space shape: (120, 12)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 13)
# Latent space shape: (120, 13)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 14)
# Latent space shape: (120, 14)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 15)
# Latent space shape: (120, 15)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 16)
# Latent space shape: (120, 16)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 17)
# Latent space shape: (120, 17)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 18)
# Latent space shape: (120, 18)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 19)
# Latent space shape: (120, 19)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 20)
# Latent space shape: (120, 20)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 21)
# Latent space shape: (120, 21)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 22)
# Latent space shape: (120, 22)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 23)
# Latent space shape: (120, 23)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 24)
# Latent space shape: (120, 24)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 25)
# Latent space shape: (120, 25)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 26)
# Latent space shape: (120, 26)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 27)
# Latent space shape: (120, 27)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 28)
# Latent space shape: (120, 28)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 29)
# Latent space shape: (120, 29)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 30)
# Latent space shape: (120, 30)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 31)
# Latent space shape: (120, 31)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 32)
# Latent space shape: (120, 32)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 33)
# Latent space shape: (120, 33)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 34)
# Latent space shape: (120, 34)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 35)
# Latent space shape: (120, 35)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 36)
# Latent space shape: (120, 36)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 37)
# Latent space shape: (120, 37)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 38)
# Latent space shape: (120, 38)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 39)
# Latent space shape: (120, 39)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 40)
# Latent space shape: (120, 40)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 41)
# Latent space shape: (120, 41)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 42)
# Latent space shape: (120, 42)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 43)
# Latent space shape: (120, 43)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 44)
# Latent space shape: (120, 44)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 45)
# Latent space shape: (120, 45)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 46)
# Latent space shape: (120, 46)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 47)
# Latent space shape: (120, 47)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 48)
# Latent space shape: (120, 48)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 49)
# Latent space shape: (120, 49)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 50)
# Latent space shape: (120, 50)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 51)
# Latent space shape: (120, 51)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 52)
# Latent space shape: (120, 52)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 53)
# Latent space shape: (120, 53)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 54)
# Latent space shape: (120, 54)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 55)
# Latent space shape: (120, 55)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 56)
# Latent space shape: (120, 56)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 57)
# Latent space shape: (120, 57)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 58)
# Latent space shape: (120, 58)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 59)
# Latent space shape: (120, 59)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 60)
# Latent space shape: (120, 60)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 61)
# Latent space shape: (120, 61)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 62)
# Latent space shape: (120, 62)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 63)
# Latent space shape: (120, 63)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 64)
# Latent space shape: (120, 64)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 65)
# Latent space shape: (120, 65)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 66)
# Latent space shape: (120, 66)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 67)
# Latent space shape: (120, 67)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 68)
# Latent space shape: (120, 68)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 69)
# Latent space shape: (120, 69)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 70)
# Latent space shape: (120, 70)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 71)
# Latent space shape: (120, 71)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 72)
# Latent space shape: (120, 72)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 73)
# Latent space shape: (120, 73)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 74)
# Latent space shape: (120, 74)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 75)
# Latent space shape: (120, 75)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 76)
# Latent space shape: (120, 76)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 77)
# Latent space shape: (120, 77)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 78)
# Latent space shape: (120, 78)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 79)
# Latent space shape: (120, 79)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 80)
# Latent space shape: (120, 80)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 81)
# Latent space shape: (120, 81)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 82)
# Latent space shape: (120, 82)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 83)
# Latent space shape: (120, 83)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 84)
# Latent space shape: (120, 84)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 85)
# Latent space shape: (120, 85)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 86)
# Latent space shape: (120, 86)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 87)
# Latent space shape: (120, 87)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 88)
# Latent space shape: (120, 88)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 89)
# Latent space shape: (120, 89)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 90)
# Latent space shape: (120, 90)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 91)
# Latent space shape: (120, 91)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 92)
# Latent space shape: (120, 92)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 93)
# Latent space shape: (120, 93)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 94)
# Latent space shape: (120, 94)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 95)
# Latent space shape: (120, 95)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 96)
# Latent space shape: (120, 96)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 97)
# Latent space shape: (120, 97)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 98)
# Latent space shape: (120, 98)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 99)
# Latent space shape: (120, 99)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 100)
# Latent space shape: (120, 100)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 101)
# Latent space shape: (120, 101)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 102)
# Latent space shape: (120, 102)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 103)
# Latent space shape: (120, 103)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 104)
# Latent space shape: (120, 104)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 105)
# Latent space shape: (120, 105)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 106)
# Latent space shape: (120, 106)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 107)
# Latent space shape: (120, 107)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 108)
# Latent space shape: (120, 108)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 109)
# Latent space shape: (120, 109)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 110)
# Latent space shape: (120, 110)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 111)
# Latent space shape: (120, 111)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 112)
# Latent space shape: (120, 112)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 113)
# Latent space shape: (120, 113)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 114)
# Latent space shape: (120, 114)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 115)
# Latent space shape: (120, 115)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 116)
# Latent space shape: (120, 116)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 117)
# Latent space shape: (120, 117)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 118)
# Latent space shape: (120, 118)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 119)
# Latent space shape: (120, 119)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 120)
# Latent space shape: (120, 120)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 121)
# Latent space shape: (120, 121)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 122)
# Latent space shape: (120, 122)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 123)
# Latent space shape: (120, 123)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 124)
# Latent space shape: (120, 124)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 125)
# Latent space shape: (120, 125)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 126)
# Latent space shape: (120, 126)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 127)
# Latent space shape: (120, 127)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 128)
# Latent space shape: (120, 128)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 129)
# Latent space shape: (120, 129)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 130)
# Latent space shape: (120, 130)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 131)
# Latent space shape: (120, 131)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 132)
# Latent space shape: (120, 132)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 133)
# Latent space shape: (120, 133)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 134)
# Latent space shape: (120, 134)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 135)
# Latent space shape: (120, 135)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 136)
# Latent space shape: (120, 136)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 137)
# Latent space shape: (120, 137)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 138)
# Latent space shape: (120, 138)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 139)
# Latent space shape: (120, 139)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 140)
# Latent space shape: (120, 140)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 141)
# Latent space shape: (120, 141)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 142)
# Latent space shape: (120, 142)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 143)
# Latent space shape: (120, 143)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 144)
# Latent space shape: (120, 144)
# Reconstructed X shape: (120, 146)
# Original X shape: (120, 146)
# Principal components shape: (146, 145)
# Latent space shape: (120, 145)
# Reconstructed X shape: (120, 146)
